# %% [markdown]
# __10.6:__  A circle has a point at its center and a radius.  Create a class Point that represents an (x-y) coordinate pair and provides x and y read-write properties for the attributes _x and _y. Include \_\_init\_\_ and \_\_repr\_\_ methods, and a move method that receives x- and y-coordinate values and sets the Point’s new location.

# %% [markdown]
# Create a class Circle that has its attributes _radius and _point (a Point that represents the Circle’s center location). Include \_\_init\_\_ and \_\_repr\_\_ methods, and a move method that receives x- and y-coordinate values and sets a new location for the Circle by calling the Point object’s move method.

# %% [markdown]
# Test your Circle class by creating a Circle object, displaying its string representation, moving the Circle and displaying its string representation again.

# %% [markdown]
# <span style="color:red;">Additions:</span> Test versions of the \_\_init\_\_ method and move method that take the x and y coordinates directly and versions that takes a Point object.  Also see what happens when you add \_\_str\_\_ methods.

# %% [markdown]
# __10.14__: The dataclasses module’s make_dataclass function creates a data class dynamically from a list of strings that represent the data class’s attributes. Research function make_dataclass, then use it to generate an Account class from the following list of strings:<br><br>
# 	[‘account’, ‘name’, ‘balance’]<br><br>
# Create objects of the new Account class, then display their string representations and compare the objects with the == and != operators

# %% [markdown]
# <span style="color:red;">Addition:</span> Now set up the Account class so that it has type annotations for each data attribute (still using the make_dataclass function), such that the account attribute should be an integer, the name should be a string, and the balance should be a Decimal.

# %% [markdown]
# <span style="color:red;">Addition:</span> Next, set up the __same__ exact Account class (keeping your test items the same) without using the make_dataclass function

# %% [markdown]
# __10.18__: Reimplement the Intro to Data Science section’s study using the Los Angeles Average January High Temperatures for 1985 through 2018, which can be found in the file ave_hi_la_jan_1895-2018.csv. How does the LA temperature trend compare to that of New York City?

# %% [markdown]
# <span style="color:red;">Addition:</span> Reimplement the same general idea using the ‘Population Time Series Data’ from Kaggle (use the POPH.csv file from the files included with this exercise, as it’s easier to use).  Note that you will need to convert the dates to an integer format.  This can be done by using the pandas.Series.str property to convert to a string (and then tatke the appropriate slice) and the pandas.to_numeric(pandas.Series) method to convert to a numeric type.  Additionally, implement a function called get_value that takes in a slope, intercept, and desired date and returns the appropriate value for that date. Then use that method to predict the current population. How accurate is it according to Google?

# %% [markdown]
# <span style="color:red;">Addition:</span> If there is time, choose a time series data from NPD, Kaggle, or another site and run a basic linear regression to get the line properties and plot the line, as done in the previous two exercises.
