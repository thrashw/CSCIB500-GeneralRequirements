# %% [markdown]
# 15.1: In part 15.6 of the chapter, you visualized the Digits dataset’s clusters using the TSNE estimator to reduce the dataset's 64 features down to 2 and then plotted the results. Reimplement that example to perform dimensionality reduction using scikit-learn's PCA estimator, then graph the results. How do the results compare to the diagram you created in section 15.6?

# %% [markdown]
# 15.2: In 15.7 of the chapter, you used the PCA estimator to reduce the Iris dataset down to 2 features and plotted the results using Seaborn. Reimplement that example using sklearn's TSNE estimator and graph the results, how do these clusters compare to what was done in the chapter?

# %% [markdown]
# Now we will visualize the digits dataset's clusters in 3 dimensions. To do this, we’ll create a 3D scatter plot using TSNE and Matplotlib’s Axes3D, which provides x-, y-, and z-axes for plotting in 3 dimensions. To do this, load the Digits dataset, create a TSNE estimator that reduces data to three dimensions and call the estimator’s fit_transform method to reduce the dataset’s dimensions. Then execute the code below (assuming you are saving your reduced data in reduced_data and the digits dataset in digits).
#
# This code imports Axes3D, creates a Figure, and calls its add_subplot method to get an Axes3D object for creating a 3D graph. Then it calls the Axes3D scatter method, specifying the x-, y-, and z- variables. If you create this graph in an ipython session (don’t forget to use the %matplotlib magic) OR set Spyder’s iPython graphics preferences to Automatic, then you can even drag the image around to see various angles.

# %%
from mpl_toolkits.mplot3d import Axes3D 
figure = plt.figure(figsize=(9,9)) 
axes = figure.add_subplot(111, projection='3d') 
dots = axes.scatter(xs=reduced_data[:, 0], ys=reduced_data[:, 1], 
                    zs=reduced_data[:, 2], c=digits.target, 
                    cmap=plt.cm.get_cmap('nipy_spectral_r', 10))

# %% [markdown]
# 15.7 – 15.9: In your book, they used unsupervised learning with the iris dataset to cluster its samples. This dataset is labeled, however, so you can use supervised learning on it. Use the techniques you learned in the Digits dataset classification to load the Iris dataset and perform classification on it with the k-nearest neighbors algorithm. Use a KNeighborsClassifer with the default k value. What is the prediction accuracy? Produce a heatmap showing the confusion matrix for this classification.
# Then, using the KFold class and cross_val_score function, determine the optimal k-value for classifying Iris samples using a KNeighborsClassifier and K-fold cross-validation

# %% [markdown]
# 15.18:In the k-NN classification example we used hyperparameter tuning to choose the best value of k. In k-means clustering, a challenge is determining the appropriate k value for clustering the data. One technique is called the elbow method. Investigate the elbow method, then use it with the Digits and Iris datasets to determine whether this technique yields the correct number of classes for each dataset.

# %% [markdown]
# 15.15: Investigate the Diabetes dataset bundled with scikit-learn. This dataset contains 442 samples, each with 10 features and a label indicating the ‘disease progression one year after baseline.” Using this dataset, reimplement the steps of this chapter’s multiple linear regression case study in Section 15.5

# %% [markdown]
# Often, when doing multiple linear regression, we don’t want to do a regression using ALL of the features. Try running the same regression from 15.15 using only a subset of the features and see how it changes your R2 score and Mean Squared Error
# If we have time, we will talk a bit at some strategies for doing feature selection, including those included in Python mentioned at https://machinelearningmastery.com/feature-selection-for-regression-data/

# %% [markdown]
# 15.4: In this chapter, we analyzed the Digits dataset and used scikit-learn’s kNeighborsClassifier to recognize the digits with high accuracy. Can humans recognize digit images as well as the kNeighborsClassifier did?
# Create a script that randomly selects and displays individual images and asks the user to enter a digit from 0 to 9 specifying the digit the image represents. Keep track of the user’s accuracy. How does the user compare to the k-nearest neighbors machine-learning algorithm?

# %% [markdown]
# 15.14. Ocean temperatures are changing fish migratory patterns. Download NOAA’s global average surface temperature anomalies time series data for 18890-2018 from
# https://www.ncdc.noaa.gov/cag/global/time-series/globe/ocean/ytd/12/1880-2018
# then load and plot the dataset using Seaborn’s regplot function. What trend do you see? (Try with different options)

# %% [markdown]
# 15.16. Feature selection involves choosing which dataset features to use when training a machine learning model. Research feature selection and scikit-learn’s feature selection capabilities
# https://scikit-learn.org/stable/modules/feature_selection.html
# Apply sklearn’s feature selection capabilities to the Digits dataset, then reimplement the classification study in Sections 15.2-15.3. Next, apply sklearn’s feature selection capabilities to the California Housing datsaset, then reimplement the linear regression case study in Section 15.5. In each case, do you get better results?

# %% [markdown]
# 15.21: In this chapter, we analyzed the Digits dataset that’s bundled with scikit-learn. This is a subset and simplified version of the original MNIST dataset, which provides 70,000 digit image samples and targets. Each sample represents a 28-by-28 image (784 features). Reimplement this chapter’s digits classification case study using MNIST. You can download MNIST in sklearn using the following statements:
#
#
#
# from sklearn.datasets import fetch_openml
#
# mnist = fetch_openml(‘mnist_784’, version=1, return_X_y=True)
